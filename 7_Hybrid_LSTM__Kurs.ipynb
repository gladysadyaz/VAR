# %% [markdown]
# <a href="https://colab.research.google.com/github/gladysadyaz/VAR/blob/main/7_Hybrid_LSTM__Kurs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import random
import warnings
import itertools
import statsmodels.api as sm
import tensorflow.keras as keras
import seaborn as sns
import tensorflow as tf
import gc

from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller
from statsmodels.tools.eval_measures import rmse, aic
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from sklearn.metrics import *
from sklearn import metrics
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping
from numpy import array

# %matplotlib inline
plt.style.use('fivethirtyeight')
warnings.filterwarnings("ignore")
# Out:
# Mounted at /content/drive

# %%
pd.options.display.float_format = '{:.2f}'.format

# %% [markdown]
# # MODELING

# %% [markdown]
# # B. LONG SHORT TERM MEMORY

# %% [markdown]
# ## Splitting & Scaling

# %%
file_path_actual = "/content/drive/My Drive/Colab Notebooks/wisman bali-kurs (1).xlsx"
df_actual = pd.read_excel(file_path_actual, sheet_name='Sheet5')
df_actual['Date'] = pd.to_datetime(df_actual['Date'], format='%d/%m/%Y')
df_actual.set_index('Date', inplace=True)
print(df_actual.head())
# Out:
#              Kurs  Wisman Bali
# Date
# 2023-01-01  15592        10626
# 2023-01-02  15572        12338
# 2023-01-03  15590        12122
# 2023-01-04  15615        11957
# 2023-01-05  15610        13463

# %%
file_path = "/content/drive/My Drive/Colab Notebooks/varx_residuals.xlsx"
df = pd.read_excel(file_path, sheet_name='FIXVAR')
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df.set_index('Date', inplace=True)
print(df.head())
# Out:
#              Kurs  Wisman Bali
# Date
# 2023-01-02 -19.95         1700
# 2023-01-03   2.17         2052
# 2023-01-04  22.77         2008
# 2023-01-05  18.88         3759
# 2023-01-06  43.49         3592

# %%
steps_slicing = 90
df_final = df_actual[:-steps_slicing]
df_update = df_actual[-steps_slicing:]

# %%
# Select only the 'Kurs Dollar' column for input and output
df_residual = df['Kurs']
data2 = df_residual.copy()
data2
# Out:
# Date
# 2023-01-02   -19.95
# 2023-01-03     2.17
# 2023-01-04    22.77
# 2023-01-05    18.88
# 2023-01-06    43.49
#               ...
# 2025-01-16   816.36
# 2025-01-17   811.41
# 2025-01-18   811.46
# 2025-01-19   811.51
# 2025-01-20   810.56
# Name: Kurs, Length: 750, dtype: float64

# %%
# Normalize the data for LSTM
scaler2 = MinMaxScaler()
scaled_data2 = scaler2.fit_transform(data2.values.reshape(-1, 1))

# %%
# Prepare the dataset for LSTM
def create_dataset(data, time_step=1):
    dataX, dataY = [], []
    for i in range(len(data)-time_step-1):
        a = data[i:(i+time_step), 0]  # Use only the first column
        dataX.append(a)
        dataY.append(data[i + time_step, 0])  # Use only the first column
    return np.array(dataX), np.array(dataY)

# %%
# Set the time step
time_step = 7

# Create the dataset for LSTM
X2, y2 = create_dataset(scaled_data2, time_step)

# Reshape X2 to be [samples, time steps, features] which is required for LSTM
X2 = X2.reshape(X2.shape[0], X2.shape[1], 1)

# %%
test_size2 = 90
train_size2 = len(X2) - test_size2
X2_train, X2_test = X2[:train_size2], X2[train_size2:]
y2_train, y2_test = y2[:train_size2], y2[train_size2:]

# %% [markdown]
# ## Hypertuning Parameters

# %%
# Function to create model for LSTM
def create_model_lstm2(units1, units2, dropout_rate, learning_rate, init_scheme):
    seed_value = 54
    random.seed(seed_value)
    np.random.seed(seed_value)
    tf.random.set_seed(seed_value)
    model = Sequential()
    model.add(LSTM(units=units1, return_sequences=True, input_shape=(time_step, 1), kernel_initializer=init_scheme))
    model.add(Dropout(rate=dropout_rate))
    model.add(LSTM(units=units2, kernel_initializer=init_scheme))
    model.add(Dropout(rate=dropout_rate))
    model.add(Dense(1, activation='linear', kernel_initializer=init_scheme))
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mean_squared_error')
    return model

# %%
# Define the hyperparameter grid for LSTM
param_grid_lstm2 = {
    'units1': [50, 100],
    'units2': [50, 100],
    'dropout_rate': [0, 0.2, 0.3],
    'learning_rate': [0.01, 0.001],
    'batch_size': [16, 32, 64, 128],
    'epochs': [100],
    'init_scheme': ['glorot_uniform','he_uniform']
}

# %%
from itertools import product
# Convert param_grid to a list of dictionaries
param_list_lstm2 = list(product(param_grid_lstm2['units1'],
                                param_grid_lstm2['units2'],
                                param_grid_lstm2['dropout_rate'],
                                param_grid_lstm2['learning_rate'],
                                param_grid_lstm2['batch_size'],
                                param_grid_lstm2['epochs'],
                                param_grid_lstm2['init_scheme'],))

# %%
from tqdm.notebook import tqdm

# Inisialisasi tracking
best_score_lstm2 = float('inf')
best_params_lstm2 = None
best_model_lstm2 = None

# Total kombinasi
total_combinations = len(param_list_lstm2)

print("Starting LSTM2 tuning...\n")

# Loop dengan tqdm
for i, params in enumerate(tqdm(param_list_lstm2, desc="LSTM2 Grid Search", unit="comb")):
    units1, units2, dropout_rate, learning_rate, batch_size, epochs, init_scheme = params

    # Cetak 1x info konfigurasi saat ini
    print(f"Training model {i+1}/{total_combinations} | "
          f"units1={units1}, units2={units2}, dropout={dropout_rate}, "
          f"lr={learning_rate}, batch={batch_size}, epochs={epochs}, init={init_scheme}")

    model_lstm2 = create_model_lstm2(units1, units2, dropout_rate, learning_rate, init_scheme)

    early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

    history_lstm2 = model_lstm2.fit(
        X2_train, y2_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data=(X2_test, y2_test),
        callbacks=[early_stopping],
        verbose=0
    )

    val_loss = min(history_lstm2.history['val_loss'])

    if val_loss < best_score_lstm2:
        best_score_lstm2 = val_loss
        best_params_lstm2 = {
            'units1': units1,
            'units2': units2,
            'dropout_rate': dropout_rate,
            'learning_rate': learning_rate,
            'batch_size': batch_size,
            'epochs': epochs,
            'init_scheme': init_scheme
        }
        best_model_lstm2 = model_lstm2

# Hasil akhir
print(f"\n Best LSTM score: {best_score_lstm2:.6f} with parameters:\n{best_params_lstm2}")
# Out:
# Starting LSTM2 tuning...
# LSTM2 Grid Search:   0%|          | 0/192 [00:00<?, ?comb/s]
# Training model 1/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 2/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 3/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 4/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 5/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 6/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 7/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 8/192 | units1=50, units2=50, dropout=0, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 9/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 10/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 11/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 12/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 13/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 14/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 15/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 16/192 | units1=50, units2=50, dropout=0, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 17/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 18/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 19/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 20/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 21/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 22/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 23/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 24/192 | units1=50, units2=50, dropout=0.2, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 25/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 26/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 27/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 28/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 29/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 30/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 31/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 32/192 | units1=50, units2=50, dropout=0.2, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 33/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 34/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 35/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 36/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 37/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 38/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 39/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 40/192 | units1=50, units2=50, dropout=0.3, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 41/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 42/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 43/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 44/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 45/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 46/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 47/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 48/192 | units1=50, units2=50, dropout=0.3, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 49/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 50/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 51/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 52/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 53/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 54/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 55/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 56/192 | units1=50, units2=100, dropout=0, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 57/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 58/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 59/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 60/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 61/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 62/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 63/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 64/192 | units1=50, units2=100, dropout=0, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 65/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 66/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 67/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 68/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 69/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 70/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 71/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 72/192 | units1=50, units2=100, dropout=0.2, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 73/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 74/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 75/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 76/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 77/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 78/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 79/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 80/192 | units1=50, units2=100, dropout=0.2, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 81/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 82/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 83/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 84/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 85/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 86/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 87/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 88/192 | units1=50, units2=100, dropout=0.3, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 89/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 90/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 91/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 92/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 93/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 94/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 95/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 96/192 | units1=50, units2=100, dropout=0.3, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 97/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 98/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 99/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 100/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 101/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 102/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 103/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 104/192 | units1=100, units2=50, dropout=0, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 105/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 106/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 107/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 108/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 109/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 110/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 111/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 112/192 | units1=100, units2=50, dropout=0, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 113/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 114/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 115/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 116/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 117/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 118/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 119/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 120/192 | units1=100, units2=50, dropout=0.2, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 121/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 122/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 123/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 124/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 125/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 126/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 127/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 128/192 | units1=100, units2=50, dropout=0.2, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 129/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 130/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 131/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 132/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 133/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 134/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 135/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 136/192 | units1=100, units2=50, dropout=0.3, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 137/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 138/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 139/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 140/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 141/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 142/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 143/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 144/192 | units1=100, units2=50, dropout=0.3, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 145/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 146/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 147/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 148/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 149/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 150/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 151/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 152/192 | units1=100, units2=100, dropout=0, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 153/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 154/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 155/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 156/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 157/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 158/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 159/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 160/192 | units1=100, units2=100, dropout=0, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 161/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 162/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 163/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 164/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 165/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 166/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 167/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 168/192 | units1=100, units2=100, dropout=0.2, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 169/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 170/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 171/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 172/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 173/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 174/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 175/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 176/192 | units1=100, units2=100, dropout=0.2, lr=0.001, batch=128, epochs=100, init=he_uniform
# Training model 177/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=16, epochs=100, init=glorot_uniform
# Training model 178/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=16, epochs=100, init=he_uniform
# Training model 179/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=32, epochs=100, init=glorot_uniform
# Training model 180/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=32, epochs=100, init=he_uniform
# Training model 181/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=64, epochs=100, init=glorot_uniform
# Training model 182/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=64, epochs=100, init=he_uniform
# Training model 183/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=128, epochs=100, init=glorot_uniform
# Training model 184/192 | units1=100, units2=100, dropout=0.3, lr=0.01, batch=128, epochs=100, init=he_uniform
# Training model 185/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=16, epochs=100, init=glorot_uniform
# Training model 186/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=16, epochs=100, init=he_uniform
# Training model 187/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=32, epochs=100, init=glorot_uniform
# Training model 188/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=32, epochs=100, init=he_uniform
# Training model 189/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=64, epochs=100, init=glorot_uniform
# Training model 190/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=64, epochs=100, init=he_uniform
# Training model 191/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=128, epochs=100, init=glorot_uniform
# Training model 192/192 | units1=100, units2=100, dropout=0.3, lr=0.001, batch=128, epochs=100, init=he_uniform
#
#  Best LSTM score: 0.000877 with parameters:
# {'units1': 100, 'units2': 100, 'dropout_rate': 0, 'learning_rate': 0.01, 'batch_size': 32, 'epochs': 100, 'init_scheme': 'he_uniform'}

# %% [markdown]
# ## Model

# %%
best_params_lstm2
# Out:
# {'units1': 100,
#  'units2': 100,
#  'dropout_rate': 0,
#  'learning_rate': 0.01,
#  'batch_size': 32,
#  'epochs': 100,
#  'init_scheme': 'he_uniform'}

# %%
# Ambil parameter terbaik dari hasil grid search
manual_units1_lstm2 = best_params_lstm2['units1']
manual_units2_lstm2 = best_params_lstm2['units2']
manual_dropout_rate_lstm2 = best_params_lstm2['dropout_rate']
manual_learning_rate_lstm2 = best_params_lstm2['learning_rate']
manual_batch_size_lstm2 = best_params_lstm2['batch_size']
manual_epochs_lstm2 = best_params_lstm2['epochs']
manual_init_scheme_lstm2 = best_params_lstm2['init_scheme']

# Buat model dengan parameter terbaik
model_manual_lstm2 = create_model_lstm2(manual_units1_lstm2,
                                        manual_units2_lstm2,
                                        manual_dropout_rate_lstm2,
                                        manual_learning_rate_lstm2,
                                        manual_init_scheme_lstm2)

# Early stopping callbacks
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=50,
                               restore_best_weights=True)

# Latih model dengan parameter terbaik
history_manual_lstm2 = model_manual_lstm2.fit(X2_train,
                                              y2_train,
                                              batch_size=manual_batch_size_lstm2,
                                              epochs=manual_epochs_lstm2,
                                              validation_data=(X2_test, y2_test),
                                              callbacks=[early_stopping],
                                              verbose=1)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - loss: 1.3115 - val_loss: 0.1182
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0402 - val_loss: 0.0304
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0059 - val_loss: 0.0058
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - val_loss: 0.0038
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0035
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0030
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - val_loss: 0.0026
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.7515e-04 - val_loss: 0.0016
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.4857e-04 - val_loss: 0.0015
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.2583e-04 - val_loss: 0.0015
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0700e-04 - val_loss: 0.0014
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.9122e-04 - val_loss: 0.0014
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.7808e-04 - val_loss: 0.0013
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6725e-04 - val_loss: 0.0013
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.5838e-04 - val_loss: 0.0012
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.5116e-04 - val_loss: 0.0012
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.4529e-04 - val_loss: 0.0012
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4051e-04 - val_loss: 0.0012
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3661e-04 - val_loss: 0.0011
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.3341e-04 - val_loss: 0.0011
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.3079e-04 - val_loss: 0.0011
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2862e-04 - val_loss: 0.0011
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2683e-04 - val_loss: 0.0011
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2535e-04 - val_loss: 0.0011
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2412e-04 - val_loss: 0.0010
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2309e-04 - val_loss: 0.0010
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.2223e-04 - val_loss: 0.0010
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2151e-04 - val_loss: 0.0010
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2089e-04 - val_loss: 0.0010
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2036e-04 - val_loss: 0.0010
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1990e-04 - val_loss: 0.0010
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1948e-04 - val_loss: 9.9979e-04
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.1910e-04 - val_loss: 9.9539e-04
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.1875e-04 - val_loss: 9.9140e-04
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.1840e-04 - val_loss: 9.8775e-04
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.1806e-04 - val_loss: 9.8440e-04
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.1771e-04 - val_loss: 9.8130e-04
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.1735e-04 - val_loss: 9.7843e-04
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.1698e-04 - val_loss: 9.7575e-04
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.1659e-04 - val_loss: 9.7325e-04
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1619e-04 - val_loss: 9.7088e-04
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1576e-04 - val_loss: 9.6864e-04
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.1532e-04 - val_loss: 9.6650e-04
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1486e-04 - val_loss: 9.6444e-04
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1439e-04 - val_loss: 9.6244e-04
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1390e-04 - val_loss: 9.6049e-04
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1340e-04 - val_loss: 9.5857e-04
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1290e-04 - val_loss: 9.5667e-04
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.1239e-04 - val_loss: 9.5479e-04
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1188e-04 - val_loss: 9.5291e-04
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1137e-04 - val_loss: 9.5103e-04
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.1087e-04 - val_loss: 9.4914e-04
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.1036e-04 - val_loss: 9.4724e-04
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0987e-04 - val_loss: 9.4533e-04
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0939e-04 - val_loss: 9.4341e-04
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.0892e-04 - val_loss: 9.4148e-04
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0846e-04 - val_loss: 9.3953e-04
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.0802e-04 - val_loss: 9.3757e-04
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0760e-04 - val_loss: 9.3560e-04
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0719e-04 - val_loss: 9.3363e-04
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.0680e-04 - val_loss: 9.3165e-04
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0644e-04 - val_loss: 9.2966e-04
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0609e-04 - val_loss: 9.2768e-04
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0576e-04 - val_loss: 9.2569e-04
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.0546e-04 - val_loss: 9.2372e-04
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0518e-04 - val_loss: 9.2175e-04
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0491e-04 - val_loss: 9.1979e-04
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.0467e-04 - val_loss: 9.1785e-04
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0445e-04 - val_loss: 9.1592e-04
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0425e-04 - val_loss: 9.1401e-04
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0406e-04 - val_loss: 9.1212e-04
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0390e-04 - val_loss: 9.1026e-04
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0375e-04 - val_loss: 9.0842e-04
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0362e-04 - val_loss: 9.0661e-04
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0350e-04 - val_loss: 9.0483e-04
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0340e-04 - val_loss: 9.0308e-04
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0331e-04 - val_loss: 9.0136e-04
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0323e-04 - val_loss: 8.9968e-04
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0317e-04 - val_loss: 8.9802e-04
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0311e-04 - val_loss: 8.9641e-04
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0306e-04 - val_loss: 8.9483e-04
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0303e-04 - val_loss: 8.9328e-04
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0299e-04 - val_loss: 8.9177e-04
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0297e-04 - val_loss: 8.9029e-04
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.0294e-04 - val_loss: 8.8885e-04
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.0292e-04 - val_loss: 8.8745e-04
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.0291e-04 - val_loss: 8.8608e-04
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.0289e-04 - val_loss: 8.8475e-04
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0287e-04 - val_loss: 8.8345e-04
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0285e-04 - val_loss: 8.8219e-04
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0282e-04 - val_loss: 8.8096e-04
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.0279e-04 - val_loss: 8.7976e-04
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.0276e-04 - val_loss: 8.7860e-04
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.0272e-04 - val_loss: 8.7748e-04

# %%
# Summary model
model_manual_lstm2.summary()
# Out:
# Model: "sequential_192"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_384 (LSTM)                      │ (None, 7, 100)              │          40,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_384 (Dropout)                │ (None, 7, 100)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_385 (LSTM)                      │ (None, 100)                 │          80,400 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_385 (Dropout)                │ (None, 100)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_192 (Dense)                    │ (None, 1)                   │             101 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 363,905 (1.39 MB)
#  Trainable params: 121,301 (473.83 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 242,604 (947.68 KB)

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(history_manual_lstm2.history['loss'], label='Training Loss', linewidth=1)
plt.plot(history_manual_lstm2.history['val_loss'], label='Validation Loss', linewidth=1)
plt.title('LSTM Model Loss\n', fontsize=14)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('LSTM Model Loss\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Predict on the training data for LSTM
train_predict_lstm2 = model_manual_lstm2.predict(X2_train)
test_predict_lstm2 = model_manual_lstm2.predict(X2_test)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
# Inverse transform the predictions for LSTM
train_predict_lstm2 = scaler2.inverse_transform(train_predict_lstm2)
test_predict_lstm2 = scaler2.inverse_transform(test_predict_lstm2)
y2_train = scaler2.inverse_transform(y2_train.reshape(-1, 1))
y2_test = scaler2.inverse_transform(y2_test.reshape(-1, 1))

# %% [markdown]
# ## Evaluation & Visualization

# %%
# Calculate MAPE for LSTM
train_mape_kurs_lstm2 = mean_absolute_percentage_error(y2_train, train_predict_lstm2)
test_mape_kurs_lstm2 = mean_absolute_percentage_error(y2_test, test_predict_lstm2)

print(f'Training MAPE (Kurs Dollar) LSTM: {train_mape_kurs_lstm2:.4f}')
print(f'Testing MAPE (Kurs Dollar) LSTM: {test_mape_kurs_lstm2:.4f}')
# Out:
# Training MAPE (Kurs Dollar) LSTM: 0.5057
# Testing MAPE (Kurs Dollar) LSTM: 0.3496

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(y2_train, label='Actual Residual (Training)', linewidth=1)
plt.plot(train_predict_lstm2, label='Predicted Residual (Training)', linewidth=1)
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('LSTM: Actual vs Predicted Kurs Dollar (Training Data Residual)\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(y2_test, label='Actual Residual(Testing)', linewidth=1)
plt.plot(test_predict_lstm2, label='Predicted Residual(Testing)', linewidth=1)
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('LSTM: Actual vs Predicted Kurs Dollar (Testing Data Residual)\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Forecasting

# %%
# Forecasting for the next 90 steps
predictions_lstm2 = []
input_data_lstm2 = scaled_data2[-time_step:].reshape(1, time_step, 1)

for _ in range(90):
    pred = model_manual_lstm2.predict(input_data_lstm2)
    predictions_lstm2.append(pred[0])
    input_data_lstm2 = np.append(input_data_lstm2[:, 1:, :], [[pred[0]]], axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
# Inverse transform the predictions to original scale
predictions_lstm2 = scaler2.inverse_transform(predictions_lstm2)

# Save predictions to DataFrame
df_future_predictions_lstm2 = pd.DataFrame(predictions_lstm2, columns=['Predicted Residual Kurs Dollar'])

# Assuming df_update is the dataframe where you want to align future predictions, here aligning index with the valid_data's last 7 steps.
df_future_predictions_lstm2.index = df_update.index

# Display the future predictions DataFrame
df_future_predictions_lstm2
# Out:
#             Predicted Residual Kurs Dollar
# Date
# 2024-10-23                          758.84
# 2024-10-24                          728.45
# 2024-10-25                          709.84
# 2024-10-26                          692.15
# 2024-10-27                          676.03
# ...                                    ...
# 2025-01-16                          383.43
# 2025-01-17                          382.44
# 2025-01-18                          381.46
# 2025-01-19                          380.49
# 2025-01-20                          379.53
#
# [90 rows x 1 columns]

# %%
# Plot Data
plt.figure(figsize=(20, 8))
plt.plot(df.iloc[-90:]['Kurs'], linewidth=1, label='History')
plt.plot(df_future_predictions_lstm2['Predicted Residual Kurs Dollar'], linewidth=1, label='Predict')
plt.xlabel('Date')
plt.ylabel('Value (Rp)')
plt.title('Plot Data Residual Kurs Dollar - Forecasting LSTM\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# # C. HYBRID VARX-LSTM

# %% [markdown]
# ## Model

# %%
file_path_forecast = "/content/drive/My Drive/Colab Notebooks/varx_forecast.xlsx"
df_forecast = pd.read_excel(file_path_forecast, sheet_name='FIXVAR')
df_forecast['Date'] = pd.to_datetime(df_forecast['Date'], format='%d/%m/%Y')
df_forecast.set_index('Date', inplace=True)
print(df_forecast.head())
# Out:
#                Kurs  Wisman Bali
# Date
# 2024-10-23 15563.19        19031
# 2024-10-24 15556.90        19251
# 2024-10-25 15558.64        20218
# 2024-10-26 15557.91        19982
# 2024-10-27 15553.73        20022

# %%
df_linear = df_forecast[['Kurs']]
df_linear
# Out:
#                Kurs
# Date
# 2024-10-23 15563.19
# 2024-10-24 15556.90
# 2024-10-25 15558.64
# 2024-10-26 15557.91
# 2024-10-27 15553.73
# ...             ...
# 2025-01-16 15561.64
# 2025-01-17 15561.59
# 2025-01-18 15561.54
# 2025-01-19 15561.49
# 2025-01-20 15561.44
#
# [90 rows x 1 columns]

# %%
df_nonlinear = df_future_predictions_lstm2.copy()
df_nonlinear
# Out:
#             Predicted Residual Kurs Dollar
# Date
# 2024-10-23                          758.84
# 2024-10-24                          728.45
# 2024-10-25                          709.84
# 2024-10-26                          692.15
# 2024-10-27                          676.03
# ...                                    ...
# 2025-01-16                          383.43
# 2025-01-17                          382.44
# 2025-01-18                          381.46
# 2025-01-19                          380.49
# 2025-01-20                          379.53
#
# [90 rows x 1 columns]

# %%
df_hybrid = pd.DataFrame({
    'Hybrid Kurs Dollar': df_linear['Kurs'] + df_nonlinear['Predicted Residual Kurs Dollar'],
})
df_hybrid
# Out:
#             Hybrid Kurs Dollar
# Date
# 2024-10-23            16322.03
# 2024-10-24            16285.35
# 2024-10-25            16268.48
# 2024-10-26            16250.06
# 2024-10-27            16229.76
# ...                        ...
# 2025-01-16            15945.07
# 2025-01-17            15944.03
# 2025-01-18            15943.00
# 2025-01-19            15941.98
# 2025-01-20            15940.97
#
# [90 rows x 1 columns]

# %%
df_hybrid_final = pd.merge(df_update['Kurs'], df_hybrid, left_index=True, right_index=True)
print(df_hybrid_final.shape)
df_hybrid_final
# Out:
# (90, 2)
#              Kurs  Hybrid Kurs Dollar
# Date
# 2024-10-23  15620            16322.03
# 2024-10-24  15593            16285.35
# 2024-10-25  15629            16268.48
# 2024-10-26  15629            16250.06
# 2024-10-27  15629            16229.76
# ...           ...                 ...
# 2025-01-16  16378            15945.07
# 2025-01-17  16373            15944.03
# 2025-01-18  16373            15943.00
# 2025-01-19  16373            15941.98
# 2025-01-20  16372            15940.97
#
# [90 rows x 2 columns]

# %% [markdown]
# ## Evaluation & Visualization

# %%
# Define true and predicted 'Close' values
y_true = df_hybrid_final['Kurs']
y_pred = df_hybrid_final['Hybrid Kurs Dollar']

# %%
mape = mean_absolute_percentage_error(y_true, y_pred) * 100  # dikali 100 agar jadi persentase
print(f"Mean Absolute Percentage Error (MAPE) for Hybrid Kurs Dollar: {mape:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE) for Hybrid Kurs Dollar: 1.68%

# %%
# Plot Data
plt.figure(figsize=(12, 6))
plt.plot(df_final.iloc[-10:]['Kurs'], linewidth=1, label='History')
plt.plot(df_hybrid_final['Kurs'], linewidth=1, label='Actual')
plt.plot(df_hybrid_final['Hybrid Kurs Dollar'], linewidth=1, label='Predict')
plt.xlabel('Date')
plt.ylabel('Value (Rp)')
plt.title('Plot Data Kurs Dollar - Forecasting Hybrid\n', fontsize=14)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
